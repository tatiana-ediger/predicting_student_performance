# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Reads data
students = pd.read_csv("student/student-all.csv")

# %%
students_df = pd.DataFrame(students)
students_df
# Out:
#       Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu  \
# 0              0     GP   F   18       U     GT3       A     4     4
# 1              1     GP   F   17       U     GT3       T     1     1
# 2              2     GP   F   15       U     LE3       T     1     1
# 3              3     GP   F   15       U     GT3       T     4     2
# 4              4     GP   F   16       U     GT3       T     3     3
# ...          ...    ...  ..  ...     ...     ...     ...   ...   ...
# 1039         644     MS   F   19       R     GT3       T     2     3
# 1040         645     MS   F   18       U     LE3       T     3     1
# 1041         646     MS   F   18       U     GT3       T     1     1
# 1042         647     MS   M   17       U     LE3       T     3     1
# 1043         648     MS   M   18       R     LE3       T     3     2
#
#           Mjob  ... goout Dalc Walc  health  absences  G1  G2  G3 Math  \
# ...

# %%
apart_port_avg = students_df.loc[(students_df["Pstatus"] == "A") & (students_df["Math"] == 0)]["G3"].mean()
apart_math_avg = students_df.loc[(students_df["Pstatus"] == "A") & (students_df["Math"] == 1)]["G3"].mean()
together_port_avg = students_df.loc[(students_df["Pstatus"] == "T") & (students_df["Math"] == 0)]["G3"].mean()
together_math_avg = students_df.loc[(students_df["Pstatus"] == "T") & (students_df["Math"] == 1)]["G3"].mean()

# %%
fig, ax = plt.subplots()
ind = np.array([1,2])
width = 0.35
plt1 = ax.bar(ind, [apart_port_avg, together_port_avg], width)
plt2 = ax.bar(ind + width, [apart_math_avg, together_math_avg], width)
ax.set_title("Class Average Grade by Parental Status")
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(("Portugese", "Math"))
ax.legend((plt1[0],plt2[0]), ("Apart", "Together"))
plt.ylim(top = 15)
plt.show()

# As we can see in this plot, there appears to be very little difference in final grade of students whose parents live together vs. apart

# %%
students_df.plot(kind="scatter", x="absences", y="G3")

# %%
students_df.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'address', 'famsize', 'Pstatus',
#        'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
#        'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'Math',
#        'Language'],
#       dtype='object')

# %%
math_avg = students_df.loc[students_df["Math"] == 1]["G3"].mean()
port_avg = students_df.loc[students_df["Math"] == 0]["G3"].mean()

# %%
plt.bar(["Portugese","Math"], [port_avg, math_avg])
plt.title("Grades by Class")
plt.show()

# %%
int_avg = students_df.loc[students_df["internet"] == "yes"]["G3"].mean()
no_int_avg = students_df.loc[students_df["internet"] == "no"]["G3"].mean()

# %%
plt.bar(["Internet", "No Internet"], [int_avg, no_int_avg])
# Out:
# <BarContainer object of 2 artists>

# %%
female_avg = students_df.loc[students_df["sex"] == "F"]["G3"].mean()
male_avg = students_df.loc[students_df["sex"] == "M"]["G3"].mean()

# %%
plt.bar(["Female", "Male"], [female_avg, male_avg])
# Out:
# <BarContainer object of 2 artists>

# %%
female_port_avg = students_df.loc[(students_df["sex"] == "F") & (students_df["Math"] == 0)]["G3"].mean()
female_math_avg = students_df.loc[(students_df["sex"] == "F") & (students_df["Math"] == 1)]["G3"].mean()
male_port_avg = students_df.loc[(students_df["sex"] == "M") & (students_df["Math"] == 0)]["G3"].mean()
male_math_avg = students_df.loc[(students_df["sex"] == "M") & (students_df["Math"] == 1)]["G3"].mean()

# %%
fig, ax = plt.subplots()
ind = np.array([1,2])
width = 0.35
plt1 = ax.bar(ind, [female_port_avg, male_port_avg], width)
plt2 = ax.bar(ind + width, [female_math_avg, male_math_avg], width)
ax.set_title("Class Average Grade by Gender")
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(("Portugese", "Math"))
ax.legend((plt1[0],plt2[0]), ("Female", "Male"))
plt.ylim(top = 15)
plt.show()

# %%
famsup_avg = students_df.loc[students_df["famsup"] == "yes"]["G3"].mean()
no_famsup_avg = students_df.loc[students_df["famsup"] == "no"]["G3"].mean()

# %%
plt.bar(["Family Support", "No Family Support"], [famsup_avg, no_famsup_avg])
# Out:
# <BarContainer object of 2 artists>

# %%
schoolsup_avg = students_df.loc[students_df["schoolsup"] == "yes"]["G3"].mean()
no_schoolsup_avg = students_df.loc[students_df["schoolsup"] == "no"]["G3"].mean()

# %%
plt.bar(["Extra School Support", "No Extra School Support"], [schoolsup_avg, no_schoolsup_avg])
# Out:
# <BarContainer object of 2 artists>

# %%
GP_port_avg = students_df.loc[(students_df["school"] == "GP") & (students_df["Math"] == 0)]["G3"].mean()
GP_math_avg = students_df.loc[(students_df["school"] == "GP") & (students_df["Math"] == 1)]["G3"].mean()
MS_port_avg = students_df.loc[(students_df["school"] == "MS") & (students_df["Math"] == 0)]["G3"].mean()
MS_math_avg = students_df.loc[(students_df["school"] == "MS") & (students_df["Math"] == 1)]["G3"].mean()

# %%
fig, ax = plt.subplots()
ind = np.array([1,2])
width = 0.35
plt1 = ax.bar(ind, [GP_port_avg, MS_port_avg], width)
plt2 = ax.bar(ind + width, [GP_math_avg, MS_math_avg], width)
ax.set_title("Class Average Grade by School")
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(("Portugese", "Math"))
ax.legend((plt1[0],plt2[0]), ("Gabriel Perreira", "Mousinho da Silva"))
plt.ylim(top = 15)
plt.show()
